# %%
# %%sql
# drop table if exists rest_api_config;
# CREATE TABLE IF NOT EXISTS rest_api_config
#     ( subject_area string ,verb string,url string,headers string,body string, params string, folder_in_adls string, is_active string)
#     using delta;
#
# --insert into rest_api_config values("pcs","post","https://api.8x8.com/customerexperience/v1/postCallSurvey/{region}",'{"8x8-apikey": "YonXyRNfVMGFcwOOe2Dna8GTHEcGHsfy", "token": "b7a8a4ba-62fb-11ea-bc55-0242ac130003", "Content-Type": "application/json"}','{"tenantId": "wolverineworldwid01", "script": "script", "rows": 500, "duration": "allhistory", "timeRange": null, "timezone": "timezone", "page": 1}','','pcs/pcs');
#
# --insert into rest_api_config values("pcs","post","https://api.8x8.com/customerexperience/v1/postCallSurvey/{region}",'{"8x8-apikey": "YonXyRNfVMGFcwOOe2Dna8GTHEcGHsfy", "token": "b7a8a4ba-62fb-11ea-bc55-0242ac130003", "Content-Type": "application/json"}','{"tenantId": "wolverineworldwid01", "script": "script", "rows": 500, "duration": "yesterday", "timeRange": null, "timezone": "timezone", "page": 1}','','pcs/pcs',1);
#
# --insert into rest_api_config values("pcs","post","https://api.8x8.com/customerexperience/v1/postCallSurvey/{region}",'{"8x8-apikey": "YonXyRNfVMGFcwOOe2Dna8GTHEcGHsfy", "token": "b7a8a4ba-62fb-11ea-bc55-0242ac130003", "Content-Type": "application/json"}','{"tenantId": "wolverineworldwid01", "script": "script", "rows": 500, "duration": null, "timeRange": "1681948860000-1682380799000", "timezone": "timezone", "page": 1}','','pcs/pcs',1);
#
#
# --insert into rest_api_config values("pcs","post","https://api.8x8.com/customerexperience/v1/postCallSurvey/{region}",'{"8x8-apikey": "YonXyRNfVMGFcwOOe2Dna8GTHEcGHsfy", "token": "b7a8a4ba-62fb-11ea-bc55-0242ac130003", "Content-Type": "application/json"}','{"tenantId": "wolverineworldwid01", "script": "script", "rows": 500, "duration": null, "timeRange": "1585713600000-1649908860000", "timezone": "timezone", "page": 1}','','pcs/pcs');
#
#
# insert into rest_api_config values("historical_analytics","post","https://api.8x8.com/oauth/v2/token",'{"Authorization": "Basic WW9uWHlSTmZWTUdGY3dPT2UyRG5hOEdUSEVjR0hzZnk6UHdPbm5OUHFRY2x5U1Axbg==","Content-Type": "application/x-www-form-urlencoded; charset=utf-8"}','{"grant_type":"client_credentials"}','','historical_analytics',1);
#
# insert into rest_api_config values("create_report","post","https://api.8x8.com/analytics/cc/v6/historical-metrics/detailed-reports",'{"Authorization": f"Bearer {access_token}","Content-Type": "application/json"}','{ "type": "detailed-reports-interaction-details","title": " All Interactions Previous Day","timezone": "America/New_York","dateRange": {"start": Previous_Date+\'T00:00:00.000Z\',"end": Previous_Date+\'T23:59:59.999Z\'}}','','historical_analytics',1);
#
# --insert into rest_api_config values("create_report","post","https://api.8x8.com/analytics/cc/v6/historical-metrics/detailed-reports",'{"Authorization": f"Bearer {access_token}","Content-Type": "application/json"}','{ "type": "detailed-reports-interaction-details","title": " All Interactions Previous Day","timezone": "America/New_York","dateRange": {"start": "2020-04-21T00:00:00.000Z","end": "2021-04-23T00:00:00.000Z"}}','','historical_analytics',1);
# --insert into rest_api_config values("create_report","post","https://api.8x8.com/analytics/cc/v6/historical-metrics/detailed-reports",'{"Authorization": f"Bearer {access_token}","Content-Type": "application/json"}','{ "type": "detailed-reports-interaction-details","title": " All Interactions Previous Day","timezone": "America/New_York","dateRange": {"start": "2021-04-01T00:00:00.000Z","end": "2022-04-01T00:00:00.000Z"}}','','historical_analytics');
# --insert into rest_api_config values("create_report","post","https://api.8x8.com/analytics/cc/v6/historical-metrics/detailed-reports",'{"Authorization": f"Bearer {access_token}","Content-Type": "application/json"}','{ "type": "detailed-reports-interaction-details","title": " All Interactions Previous Day","timezone": "America/New_York","dateRange": {"start": "2022-04-01T00:00:00.000Z","end": "2023-04-20T00:00:00.000Z"}}','','historical_analytics');
#
# insert into rest_api_config values("access_report","get","http://api.8x8.com/analytics/cc/v6/historical-metrics/detailed-reports",'{"Authorization": f"Bearer {access_token}","Content-Type": "application/json"}','','','historical_analytics',1);
#
# insert into rest_api_config values("ccrt", "post","https://api.8x8.com/oauth/v2/token",'{"Content-Type": "application/x-www-form-urlencoded","Authorization": "Basic WW9uWHlSTmZWTUdGY3dPT2UyRG5hOEdUSEVjR0hzZnk6UHdPbm5OUHFRY2x5U1Axbg=="}','{"grant_type":"client_credentials"}','','',1);
#
# insert into rest_api_config values("queue", "get","https://api.8x8.com/analytics/cc/v5/realtime-metrics/queues",'{"Authorization": f"Bearer {queue_token}","Content-Type": "application/json"}','','{"page": "0","size": "100","metrics": "entered.today"}','pcs/queue',1);
#
# insert into rest_api_config values("group_id", "get","https://api.8x8.com/analytics/cc/v5/realtime-metrics/groups",'{"Authorization": f"Bearer {queue_token}","Content-Type": "application/json"}','','{"page": "0","size": "100","metrics": "enabled.rt"}','pcs/group_id',1);
#
# insert into rest_api_config values("agents", "get",'f"https://api.8x8.com/analytics/cc/v5/realtime-metrics/groups/{group_id}/agents"','{"Authorization": f"Bearer {queue_token}","Content-Type": "application/json"}','','{"page": "0","size": "100","metrics": "offered.today"}','pcs/agents',1);

# %%
  # %%sql
--select 1
--  update rest_api_config 
--  set body = '{ "type": "detailed-reports-interaction-details","title": " All Interactions Previous Day","timezone": "America/New_York","dateRange": {"start": "2023-04-21T00:00:00.000Z","end": "2023-04-30T00:00:00.000Z"}}'
--   where subject_area = 'create_report';

-- update rest_api_config 
--   set body = '{"tenantId": "wolverineworldwid01", "script": "script", "rows": 500, "duration": null, "timeRange": "1682654401000-1682827199000", "timezone": "timezone", "page": 1}'
--    where subject_area = 'pcs';
--select unix_timestamp(to_timestamp('2023-05-14 04:00:00')) 1684036800
--select unix_timestamp(to_timestamp('2023-05-15 04:00:00')) 1684123200
-- update rest_api_config 
--   set body = '{"tenantId": "wolverineworldwid01", "script": "script", "rows": 500, "duration": null, "timeRange": "1683950400000-1684036800000", "timezone": "timezone", "page": 1}'
--    where subject_area = 'pcs';


--  update rest_api_config 
--  set body = '{ "type": "detailed-reports-interaction-details","title": " All Interactions Previous Day","timezone": "America/New_York","dateRange": {"start": Previous_Date+\'T00:00:00.000Z\',"end": Previous_Date+\'T23:59:59.999Z\'}}'
--   where subject_area = 'create_report';

-- update rest_api_config 
--   set body = '{"tenantId": "wolverineworldwid01", "script": "script", "rows": 500, "duration": "yesterday", "timeRange": null, "timezone": "timezone", "page": 1}'
--    where subject_area = 'pcs';

-- update rest_api_config 
-- set body = '{ "type": "detailed-reports-interaction-details","title": " All Interactions Previous Day","timezone": "America/New_York","dateRange": {"start": "2023-10-02T00:00:00.000Z","end": "2023-10-05T00:00:00.000Z"},"includeParticipants": True}'
--  where subject_area = 'create_report';
 
 update rest_api_config 
set body = '{ "type": "detailed-reports-interaction-details","title": " All Interactions Previous Day","timezone": "America/New_York","dateRange": {"start": Previous_Date+\'T00:00:00.000Z\',"end": Previous_Date+\'T23:59:59.999Z\'},"includeParticipants": True}'
  where subject_area = 'create_report';

# %%
# %%sql
#
# --select to_timestamp('2023-05-13 04:01:00', 'yyyy-MM-dd HH:mm:ss');
# select unix_timestamp(to_timestamp('2023-05-13 04:01:00', 'yyyy-MM-dd HH:mm:ss')); --1683950400
# --select unix_timestamp(to_timestamp('2023-05-14 04:00:00')) ;--1684036800

# %%
# %%sql
# select * from rest_api_config;

# %%
# %%sql
# drop table IF EXISTS language_codes;
# CREATE TABLE IF NOT EXISTS language_codes (language_short_nm string, language_long_nm string);
# insert into language_codes values ('EN','English');
# insert into language_codes values('ES','Spanish');
# insert into language_codes values ('FR','French');
# insert into language_codes values ('DE','German');
# insert into language_codes values ('IT','Italian');
# insert into language_codes values ('NL','Dutch');
